# %%
import pickle
import gzip
import pprint as pp

# We define the functions used to load and save objects

def save_object(obj, filename):

    """
    Function that saves an object to a file using pickle
    """

    result = pickle.dumps(obj)
    with gzip.GzipFile(filename, 'wb') as dest: dest.write(result)
    dest.close()


def load_object(filename):

    """
    Function that loads an object from a file using pickle
    """
    with gzip.GzipFile(filename, 'rb') as f:
        u = pickle._Unpickler(f)
        u.encoding = 'latin1'
        p = u.load()
        pp.pprint(p[0:10])

load_object('random_evaluations.dat')
# Out:
# [[{'dropout': array([ 0.12093303]),
#    'droptrain': 0.0,
#    'int_bits': 8,
#    'int_bits_fraction': array([ 0.39676747]),
#    'lg_partition': 2,
#    'lg_unrolling': 1,
#    'log_l2_reg': array([-9.99897063]),
#    'log_lrate_halflife': 7.0,
#    'log_lrate_initial': array([-2.55973233]),
#    'momentum_final': 0.0,
#    'momentum_initial': 0.0,
#    'num_hidden_units': array([68, 68, 68], dtype=int64),
#    'pipelining': 1,
#    'total_bits_over_4': 5},
#   {'ll_val_task': -2.7479947343539401, 'power_task': 1.53314688444}],
#  [{'dropout': array([ 0.35637774]),
#    'droptrain': 0.0,
#    'int_bits': 24,
#    'int_bits_fraction': array([ 0.99336617]),
#    'lg_partition': 1,
#    'lg_unrolling': 2,
#    'log_l2_reg': array([-9.47521663]),
#    'log_lrate_halflife': 7.0,
#    'log_lrate_initial': array([-1.9740819]),
#    'momentum_final': 0.0,
#    'momentum_initial': 0.0,
#    'num_hidden_units': array([121, 121, 121], dtype=int64),
#    'pipelining': 1,
#    'total_bits_over_4': 6},
#   {'ll_val_task': 2.2321537703600325, 'power_task': 5.007813950399999}],
#  [{'dropout': array([ 0.05973096]),
#    'droptrain': 0.0,
#    'int_bits': 3,
#    'int_bits_fraction': array([ 0.24721062]),
#    'lg_partition': 1,
#    'lg_unrolling': 2,
#    'log_l2_reg': array([-9.89826238]),
#    'log_lrate_halflife': 7.0,
#    'log_lrate_initial': array([-2.18069709]),
#    'momentum_final': 0.0,
#    'momentum_initial': 0.0,
#    'num_hidden_units': array([224, 224, 224], dtype=int64),
#    'pipelining': 1,
#    'total_bits_over_4': 3},
#   {'ll_val_task': 0.58014165283965013, 'power_task': 17.936362375199998}],
#  [{'dropout': array([ 0.0237159]),
#    'droptrain': 0.0,
#    'int_bits': 7,
#    'int_bits_fraction': array([ 0.53462262]),
#    'lg_partition': 1,
#    'lg_unrolling': 5,
#    'log_l2_reg': array([-6.89764265]),
#    'log_lrate_halflife': 7.0,
#    'log_lrate_initial': array([-1.34566699]),
#    'momentum_final': 0.0,
#    'momentum_initial': 0.0,
#    'num_hidden_units': array([51, 51, 51], dtype=int64),
#    'pipelining': 1,
#    'total_bits_over_4': 3},
#   {'ll_val_task': -2.9215189217700539, 'power_task': 1.40316213606}],
#  [{'dropout': array([ 0.33833215]),
#    'droptrain': 0.0,
#    'int_bits': 12,
#    'int_bits_fraction': array([ 0.58760679]),
#    'lg_partition': 2,
#    'lg_unrolling': 4,
#    'log_l2_reg': array([-6.06197948]),
#    'log_lrate_halflife': 7.0,
#    'log_lrate_initial': array([-2.53726601]),
#    'momentum_final': 0.0,
#    'momentum_initial': 0.0,
#    'num_hidden_units': array([167, 167, 167], dtype=int64),
#    'pipelining': 1,
#    'total_bits_over_4': 5},
#   {'ll_val_task': -3.0434753172088977, 'power_task': 7.961989995}],
#  [{'dropout': array([ 0.2232339]),
#    'droptrain': 0.0,
#    'int_bits': 5,
#    'int_bits_fraction': array([ 0.52449553]),
#    'lg_partition': 3,
#    'lg_unrolling': 0,
#    'log_l2_reg': array([-8.89587937]),
#    'log_lrate_halflife': 7.0,
#    'log_lrate_initial': array([-0.70064862]),
#    'momentum_final': 0.0,
#    'momentum_initial': 0.0,
#    'num_hidden_units': array([140, 140, 140], dtype=int64),
#    'pipelining': 1,
#    'total_bits_over_4': 2},
#   {'ll_val_task': 1.4988306029693088, 'power_task': 8.821854329399999}],
#  [{'dropout': array([ 0.19154757]),
#    'droptrain': 0.0,
#    'int_bits': 17,
#    'int_bits_fraction': array([ 0.58296897]),
#    'lg_partition': 0,
#    'lg_unrolling': 3,
#    'log_l2_reg': array([-8.130758]),
#    'log_lrate_halflife': 7.0,
#    'log_lrate_initial': array([-2.573949]),
#    'momentum_final': 0.0,
#    'momentum_initial': 0.0,
#    'num_hidden_units': array([81, 81, 81], dtype=int64),
#    'pipelining': 1,
#    'total_bits_over_4': 7},
#   {'ll_val_task': -2.8304637653357854, 'power_task': 4.0464591183}],
#  [{'dropout': array([ 0.19204191]),
#    'droptrain': 0.0,
#    'int_bits': 22,
#    'int_bits_fraction': array([ 0.75564552]),
#    'lg_partition': 3,
#    'lg_unrolling': 2,
#    'log_l2_reg': array([-3.31925096]),
#    'log_lrate_halflife': 7.0,
#    'log_lrate_initial': array([-2.37340007]),
#    'momentum_final': 0.0,
#    'momentum_initial': 0.0,
#    'num_hidden_units': array([177, 177, 177], dtype=int64),
#    'pipelining': 1,
#    'total_bits_over_4': 7},
#   {'ll_val_task': -2.9153490409823619, 'power_task': 8.057106644400001}],
#  [{'dropout': array([ 0.06235244]),
#    'droptrain': 0.0,
#    'int_bits': 4,
#    'int_bits_fraction': array([ 0.31699691]),
#    'lg_partition': 4,
#    'lg_unrolling': 0,
#    'log_l2_reg': array([-5.13117581]),
#    'log_lrate_halflife': 7.0,
#    'log_lrate_initial': array([-0.60864943]),
#    'momentum_final': 0.0,
#    'momentum_initial': 0.0,
#    'num_hidden_units': array([149, 149, 149], dtype=int64),
#    'pipelining': 1,
#    'total_bits_over_4': 3},
#   {'ll_val_task': -0.52664383420598093, 'power_task': 10.060647305399998}],
#  [{'dropout': array([ 0.1448741]),
#    'droptrain': 0.0,
#    'int_bits': 1,
#    'int_bits_fraction': array([ 0.08569041]),
#    'lg_partition': 5,
#    'lg_unrolling': 4,
#    'log_l2_reg': array([-1.9104917]),
#    'log_lrate_halflife': 7.0,
#    'log_lrate_initial': array([-1.57997571]),
#    'momentum_final': 0.0,
#    'momentum_initial': 0.0,
#    'num_hidden_units': array([154, 154, 154], dtype=int64),
#    'pipelining': 1,
#    'total_bits_over_4': 1},
#   {'ll_val_task': 2.2344413216965493, 'power_task': 5.244709446}]]
